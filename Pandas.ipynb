# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')
df_xls = pd.read_excel('pokemon_data.xlsx')
df_tab = pd.read_csv('pokemon_data.txt', delimiter = '\t')

# %%
# print(df)
# print(df.head(5))
# print(df.tail(5))

# print(df_xls)
# print(df_xls.head(5))
# print(df_xls.tail(5))

# print(df_tab)
# print(df_tab.head(5))
# print(df_tab.tail(5))
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# Read Columns and Rows

# %%
# df.columns
# print(df[['Name','Type 1', 'HP']])

# print(df.iloc[:])
# print(df.iloc[0:4])
# print(df.iloc[2,1])
# for k,v in df.iterrows():
#     print(k,v['Name'])

# df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# sorting data

# %%
# df.sort_values('Name', ascending=False)

# df.sort_values(['Name','Type 1'], ascending=[1,1])
# df.sort_values(['Name','Type 1'], ascending=[1,0])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Making  changes in data

# %%
# df['Total']= df.iloc[:,4:10].sum(axis = 1)
# df

cols = list(df.columns)
df = df[cols[0:4]+ [cols[-1]] + cols[4:12]]
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Exporting data

# %%
df.to_csv('modified.csv', index = False)
df.to_excel('modified.xlsx', index = False)
df.to_csv('modified.txt', index = False, sep = '\t')

# %%
# Filtering the data

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
new_df = new_df.reset_index(drop = True)
new_df

df.loc[df['Name'].str.contains('Mega')]
df.loc[(df['Type 1'].str.contains('Fire|Grass')) & (df['Type 2'].str.contains('Ice')) ]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
# Regular expression

# %%
# Out:
#        #                     Name Type 1 Type 2  Total  HP  Attack  Defense  \
# 509  459                   Snover  Grass    Ice    334  60      62       50
# 510  460                Abomasnow  Grass    Ice    494  90      92       75
# 511  460  AbomasnowMega Abomasnow  Grass    Ice    594  90     132      105
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 509       62       60     40           4      False
# 510       92       85     60           4      False
# 511      132      105     30           4      False

# %%
import re

# df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]

df.loc[df['Name'].str.contains('^pi[a-z]*', flags = re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    251   40      45
# 21    17            Pidgeotto    Normal    Flying    349   63      60
# 22    18              Pidgeot    Normal    Flying    479   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 30    25              Pikachu  Electric       NaN    320   35      55
# 136  127               Pinsir       Bug       NaN    500   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying    600   65     155
# 186  172                Pichu  Electric       NaN    205   20      40
# 219  204               Pineco       Bug       NaN    290   50      65
# 239  221            Piloswine       Ice    Ground    450  100     100
# 438  393               Piplup     Water       NaN    314   53      51
# 558  499              Pignite      Fire  Fighting    418   90      93
# ...

# %%
df.loc[df['Name'] == 'Pidgey', 'Type 1']= 'Wow'

df.loc[df['Name'] == 'Pidgey', 'Type 1']= 'Wow'
df.loc[df['Total']>400, ['Generation','Legendary']] = 'Test Vale'
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# df.groupby(['Name']).sum().sort_values('Attack', ascending=False)

# df.groupby(['Name']).sum()['Attack']

df.groupby(['Name','Type 1']).sum().sort_values('Attack', ascending=False)
# Out:
# /var/folders/3x/k4gl7n_s4fq55tddnrhbbrch0000gp/T/ipykernel_23895/3476483917.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Name','Type 1']).sum().sort_values('Attack', ascending=False)
#                                    #   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name                    Type 1
# MewtwoMega Mewtwo X     Psychic  150  106     190      100      154      100
# HeracrossMega Heracross Bug      214   80     185      115       40      105
# GroudonPrimal Groudon   Ground   383  100     180      160      150       90
# DeoxysAttack Forme      Psychic  386   50     180       20      180       20
# RayquazaMega Rayquaza   Dragon   384  105     180      100      180      100
# ...                              ...  ...     ...      ...      ...      ...
# ...
